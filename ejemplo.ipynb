# %%
import pandas as pd
import tabulate as tb

# %%
data = pd.read_csv('data.csv', sep=';')
data
# Out:
#         AÑO  MES  DIA                REGION      COMUNA  TOTAL
# 0      2021    8    5  I Región de Tarapacá     IQUIQUE     19
# 1      2021    2   10  I Región de Tarapacá     IQUIQUE     14
# 2      2021    5    7  I Región de Tarapacá     IQUIQUE     16
# 3      2021   11   23  I Región de Tarapacá     IQUIQUE     16
# 4      2021    3   10  I Región de Tarapacá     IQUIQUE     10
# ...     ...  ...  ...                   ...         ...    ...
# 18437  2021    5   10  XVI Región del Ñuble  SAN CARLOS      4
# 18438  2021    6    3  XVI Región del Ñuble     CHILLÁN     12
# 18439  2021    7    8  XVI Región del Ñuble      BULNES      1
# 18440  2021   11   10  XVI Región del Ñuble     CHILLÁN      9
# 18441  2021    1   14  XVI Región del Ñuble      BULNES      1
#
# [18442 rows x 6 columns]

# %%
print(tb.tabulate(data, headers='keys', tablefmt='psql'))
# Out:
# +-------+-------+-------+-------+--------------------------------------------------------+----------------------+---------+
# |       |   AÑO |   MES |   DIA | REGION                                                 | COMUNA               |   TOTAL |
# |-------+-------+-------+-------+--------------------------------------------------------+----------------------+---------|
# |     0 |  2021 |     8 |     5 | I Región de Tarapacá                                   | IQUIQUE              |      19 |
# |     1 |  2021 |     2 |    10 | I Región de Tarapacá                                   | IQUIQUE              |      14 |
# |     2 |  2021 |     5 |     7 | I Región de Tarapacá                                   | IQUIQUE              |      16 |
# |     3 |  2021 |    11 |    23 | I Región de Tarapacá                                   | IQUIQUE              |      16 |
# ...
